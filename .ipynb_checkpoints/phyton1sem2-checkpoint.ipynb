# %%
age = 3
for age in range(5):
    print (age)

#def data1():
#    age = 3 
#   high = 2
#    return age + high
#print (age)
#result = data1()
#print (result)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
x ="waw"

def myfunc():
    global x
    x ="yes"
    
result=myfunc()

print("me is"+[result])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 9
#       5     x ="yes"
#       7 result=myfunc()
# ----> 9 print("me is"+[result])
#
# TypeError: can only concatenate str (not "list") to str

# %%
kota = "tangerang"
print(kota)
print(kota[2])
print(kota[-3])
print(kota[::-1])
print(kota[0:4:1])
# Out:
# tangerang
# n
# a
# gnaregnat
# tang

# %%
data =[False, 2, 3, "Empat"]
print(data)
print(data[3])
# Out:
# [False, 2, 3, 'Empat']
# Empat
