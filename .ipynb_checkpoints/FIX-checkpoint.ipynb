# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import TfidfVectorizer

# 1. Load dataset
train_data = pd.read_csv('trainto.csv')  # Data training (ada label)
test_data = pd.read_csv('testBenar.csv')    # Data testing (hanya id dan text)

print("Training data columns:", train_data.columns.tolist())
print("Test data columns:", test_data.columns.tolist())

# 2. Pisahkan features dan target dari training data
X_train_raw = train_data['text']  # Kolom text dari training (MASIH TEXT)
y_train = train_data['label']     # Kolom label dari training

# 3. Test data hanya punya id dan text
test_ids = test_data['id']        # Kolom id dari test
X_test_raw = test_data['text']    # Kolom text dari test (MASIH TEXT)

print(f"\nContoh text data:")
print(f"Training: {X_train_raw.iloc[0][:60]}...")
print(f"Test: {X_test_raw.iloc[0][:10]}...")

# 4. PREPROCESSING PENTING: Convert Text to Numbers
vectorizer = TfidfVectorizer(
    max_features=350,      # Batasi jumlah fitur
    ngram_range=(1, 2),     # Gunakan unigram dan bigram
     min_df=2,                    # Ignore terms that appear in less than 2 documents
    max_df=0.8,                  # Ignore terms that appear in more than 80% of documents
    lowercase=True,              # Convert to lowercase
    sublinear_tf=True            # Use sublinear tf scaling
)

# Fit pada training data, transform kedua dataset
print("\n🔄 Converting text to numerical features...")
X_train = vectorizer.fit_transform(X_train_raw)  # Convert training text to numbers
X_test = vectorizer.transform(X_test_raw)        # Convert test text to numbers

print(f"✅ Conversion successful!")
print(f"X_train shape: {X_train.shape}")  # (samples, features)
print(f"X_test shape: {X_test.shape}")    # (samples, features)

# 5. Train Model Decision Tree
print("\n🤖 Training Decision Tree model...")
dt_model = DecisionTreeClassifier(
    random_state=42,
    max_depth=75,           # Kontrol kedalaman
    min_samples_split=70,   # Minimal samples untuk split
    min_samples_leaf=10     # Minimal samples di leaf
)

dt_model.fit(X_train, y_train)
print("✅ Model trained successfully!")

# 6. Predict pada test data
print("\n🔮 Making predictions...")
predictions = dt_model.predict(X_test)
probabilities = dt_model.predict_proba(X_test)

# 7. Simpan hasil prediksi
results = pd.DataFrame({
    'id': test_ids,
    'text': X_test_raw,
    'predicted_label': predictions,
    'confidence': np.max(probabilities, axis=1)  # Confidence score
})

# 8. Tampilkan hasil
print(f"\n📋 Hasil Prediksi:")
print(results.head(20))

print(f"\n📊 Distribusi Prediksi:")
print(results['predicted_label'].value_counts())

print(f"\nℹ️  Jumlah fitur yang digunakan: {X_train.shape[1]}")
print(f"ℹ️  Classes yang diprediksi: {dt_model.classes_}")
# Out:
# Training data columns: ['text', 'label']
# Test data columns: ['id', 'text']
#
# Contoh text data:
# Training: @hyalfay @NatharElyas @BosPurwa @NatharElyas @BosPurwa Prabo...
# Test: @xuminghao...
#
# 🔄 Converting text to numerical features...
# ✅ Conversion successful!
# X_train shape: (5000, 350)
# X_test shape: (5000, 350)
#
# 🤖 Training Decision Tree model...
# ✅ Model trained successfully!
#
# 🔮 Making predictions...
#
# 📋 Hasil Prediksi:
#     id                                               text predicted_label  \
# 0    0  @xuminghao_ogf @ShopeeID @ShopeePay_ID Bapak g...       reformasi
# 1    1  tidak hanya membayangkan masa depan sebagai ki...      pemerataan
# 2    2  @feliscxtus Kalau aku jadi pemimpin RI visiku ...             sdm
# 3    3  @EkoDwiSant73293 @Dahnilanzar @prabowo Masyara...             sdm
# 4    4  @goonjol Mengamankan data pribadi rakyat RI si...       reformasi
# 5    5  @Mdy_Asmara1701 Omon-omon doang wo @prabowo. P...      hilirisasi
# 6    6  @CNNIndonesia @KPK_RI ayo tangkap kader PDI-P ...       reformasi
# 7    7  Udah gak bener Prabowo kelola ini negara : Sat...      pemerataan
# 8    8  Contoh 3 Literasi media bertujuan agar generas...       pekerjaan
# 9    9  @awesomeposted Coba perhatikan nie pa presiden...      pertahanan
# 10  10  Padahal: Banyak kritik Gen Z bersumber dari li...      pertahanan
# 11  11  @kucingtelorasin @KokoprotKesang @MkarimAhusni...       reformasi
# 12  12  Program Asta Cita adalah program yg dibentuk u...      pertahanan
# 13  13   @Lembayung071 @gibran_tweet @prabowo @Dedynur...       reformasi
# 14  14  @mas_veel @prabowo @gibran_tweet Penjilat Muly...         harmoni
# 15  15  Penegakan hukum yang tegas dan transparan adal...        ideologi
# 16  16  @azizbas_ @ecommurz Ya saya bisa diblokir oleh...       reformasi
# 17  17  Jangan cuma ngajarin anak-anak cara main game ...      pertahanan
# 18  18  @tanyakanrl Banyak masyarakat tertipu melalui ...      pertahanan
# 19  19  @ZulkifliLubis69 @jokowi Eh zul Lu mau khianat...       pekerjaan
#
#     confidence
# 0     0.512821
# 1     0.244898
# 2     0.566667
# 3     0.566667
# 4     1.000000
# 5     0.352941
# 6     0.562500
# 7     0.244898
# 8     0.227273
# 9     0.380952
# 10    0.434783
# 11    0.512821
# 12    0.619048
# 13    0.285714
# 14    0.437500
# 15    1.000000
# 16    0.512821
# 17    0.640000
# 18    0.218750
# 19    0.366667
#
# 📊 Distribusi Prediksi:
# predicted_label
# pertahanan    1604
# reformasi      981
# pekerjaan      570
# ideologi       565
# harmoni        390
# pemerataan     357
# hilirisasi     286
# sdm            247
# Name: count, dtype: int64
#
# ℹ️  Jumlah fitur yang digunakan: 350
# ℹ️  Classes yang diprediksi: ['harmoni' 'hilirisasi' 'ideologi' 'pekerjaan' 'pemerataan' 'pertahanan'
#  'reformasi' 'sdm']
