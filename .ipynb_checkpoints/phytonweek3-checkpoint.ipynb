# %%
import numpy as DTZ

B = DTZ.array([[ 8.2, 7.5, 6], [4, 3.5, 3 ]])
B
# Out:
# array([[8.2, 7.5, 6. ],
#        [4. , 3.5, 3. ]])

# %%
import numpy as np

B = np.array([[ 82, 75, 6], [4, 35, 3 ]])
B
# Out:
# array([[82, 75,  6],
#        [ 4, 35,  3]])

# %%
B.dtype
# Out:
# dtype('int32')

# %%
import numpy as np
A = np.array([[2, 4], [5, 8],[7, 2], [2, 9]])
print ("Matriks A:")
A
# Out:
# Matriks A:
# array([[2, 4],
#        [5, 8],
#        [7, 2],
#        [2, 9]])

# %%
print ("Elemen Matrik Baris 3 kolom 2:")
A[3, 1]
# Out:
# Elemen Matrik Baris 3 kolom 2:
# 9

# %%
B = np.array([[1, 3], [2, 4], [5, 2],[2,3]])
B
# Out:
# array([[1, 3],
#        [2, 4],
#        [5, 2],
#        [2, 3]])

# %%
Y = A - B
Y
# Out:
# array([[1, 1],
#        [3, 4],
#        [2, 0],
#        [0, 6]])

# %%
Y.T
# Out:
# array([[1, 3, 2, 0],
#        [1, 4, 0, 6]])

# %%
Y/4
# Out:
# array([[0.25, 0.25],
#        [0.75, 1.  ],
#        [0.5 , 0.  ],
#        [0.  , 1.5 ]])

# %%
np.sum(A)
# Out:
# 39

# %%
np. sum(A, axis=0)
# Out:
# array([16, 23])
